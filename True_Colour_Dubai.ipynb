# %% [markdown]
# # **True Colour Image of Dubai from 1995**

# %%
import ee
import geemap

# Authenticate and Initialize Earth Engine with your project ID
ee.Initialize(project='ee-dkloer01')

# Shapefile einladen (Pfad zur Datei anpassen)
shapefile_path = "C:/Users/dkloe/Downloads/Dubai_Shapes/Dubai.shp"
dubai = geemap.shp_to_ee(shapefile_path)

# Load the Landsat 8 Surface Reflectance Dataset
dataset = ee.ImageCollection('LANDSAT/LT05/C02/T1_L2').filterDate('1995-01-01', '1995-12-31').filterBounds(dubai)

# Apply Scaling Factors.
def apply_scale_factors(image):
  optical_bands = image.select('SR_B.').multiply(0.0000275).add(-0.2)
  thermal_bands = image.select('ST_B6').multiply(0.00341802).add(149.0)
  return image.addBands(optical_bands, None, True).addBands(
      thermal_bands, None, True
  )


dataset = dataset.map(apply_scale_factors).median()

visualization = {
    'bands': ['SR_B3', 'SR_B2', 'SR_B1'],
    'min': 0.0,
    'max': 0.3,
}

# Create an interactive Map
map = geemap.Map(center=[25.07, 55.18], zoom=10)

# Add the Dataset to the Map
map.add_layer(dataset.clip(dubai), visualization, 'RGB Dubai 1995')

# Show the Map
map
# Out:
# Map(center=[25.07, 55.18], controls=(WidgetControl(options=['position', 'transparent_bg'], widget=SearchDataGU…

# %% [markdown]
# # **True Colour Image of Dubai from 2005**

# %%
import ee
import geemap


# Load the Landsat 8 Surface Reflectance Dataset
dataset = ee.ImageCollection('LANDSAT/LE07/C02/T1_L2').filterDate('2005-01-01', '2005-12-31').filterBounds(dubai)

# Apply Scaling Factors.
def apply_scale_factors(image):
  optical_bands = image.select('SR_B.').multiply(0.0000275).add(-0.2)
  thermal_bands = image.select('ST_B6').multiply(0.00341802).add(149.0)
  return image.addBands(optical_bands, None, True).addBands(
      thermal_bands, None, True
  )


dataset = dataset.map(apply_scale_factors).median()

visualization = {
    'bands': ['SR_B3', 'SR_B2', 'SR_B1'],
    'min': 0.0,
    'max': 0.3,
}

# Create an interactive Map
map = geemap.Map(center=[25.07, 55.18], zoom=10)

# Add the Dataset to the Map
map.add_layer(dataset.clip(dubai), visualization, 'RGB Dubai 2005')

# Show the Map
map
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# Map(center=[25.07, 55.18], controls=(WidgetControl(options=['position', 'transparent_bg'], widget=SearchDataGU…

# %% [markdown]
# # **True Colour Image of Dubai from 2015**

# %%
import ee
import geemap


# Load the Landsat 8 Surface Reflectance Dataset
dataset = ee.ImageCollection('LANDSAT/LC08/C02/T1_L2').filterDate('2015-01-01', '2015-12-31').filterBounds(dubai)

# Apply Scaling Factors.
def apply_scale_factors(image):
  optical_bands = image.select('SR_B.').multiply(0.0000275).add(-0.2)
  thermal_bands = image.select('SR_B6').multiply(0.00341802).add(149.0)
  return image.addBands(optical_bands, None, True).addBands(
      thermal_bands, None, True
  )


dataset = dataset.map(apply_scale_factors).median()

visualization = {
    'bands': ['SR_B4', 'SR_B3', 'SR_B2'],
    'min': 0.0,
    'max': 0.3,
}

# Create an interactive Map
map = geemap.Map(center=[25.07, 55.18], zoom=10)

# Add the Dataset to the Map
map.add_layer(dataset.clip(dubai), visualization, 'True Color (321)')

# Show the Map
map
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# Map(center=[25.07, 55.18], controls=(WidgetControl(options=['position', 'transparent_bg'], widget=SearchDataGU…

# %% [markdown]
# # **True Colour Image of Dubai from 2024**

# %%
import ee
import geemap


# Load the Landsat 8 Surface Reflectance Dataset
dataset = ee.ImageCollection('LANDSAT/LC08/C02/T1_L2').filterDate('2024-01-01', '2024-12-31').filterBounds(dubai)

# Apply Scaling Factors.
def apply_scale_factors(image):
  optical_bands = image.select('SR_B.').multiply(0.0000275).add(-0.2)
  thermal_bands = image.select('SR_B6').multiply(0.00341802).add(149.0)
  return image.addBands(optical_bands, None, True).addBands(
      thermal_bands, None, True
  )


dataset = dataset.map(apply_scale_factors).median()

visualization = {
    'bands': ['SR_B4', 'SR_B3', 'SR_B2'],
    'min': 0.0,
    'max': 0.3,
}

# Create an interactive Map
map = geemap.Map(center=[25.07, 55.18], zoom=10)

# Add the Dataset to the Map
map.add_layer(dataset.clip(dubai), visualization, 'RGB Dubai 2024')

# Show the Map
map
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# Map(center=[25.07, 55.18], controls=(WidgetControl(options=['position', 'transparent_bg'], widget=SearchDataGU…
